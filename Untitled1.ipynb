# %% [markdown]
# 1.Write a python program to get the character at index 7 of the string s = "Hello, World!"

# %%
s = "Hello, World!"
s[7]
# Out:
# 'W'

# %% [markdown]
# 2.Write a python program to get the character at index -2 of the string s = "python."

# %%
s = "python"
s[-2]
# Out:
# 'o'

# %% [markdown]
# 3.Write a python program to get a string from a mgiven string where all occurrence of "r" have been changed to $.

# %%
s = "restart"
s.replace('r','$')
# Out:
# '$esta$t'

# %% [markdown]
# 4.How do you find the length of a given string?

# %%
s = "innomatic"
len(s)
# Out:
# 9

# %% [markdown]
# 5.How do you convert a string to uppercase or lowercase?

# %%
a = "innomatic"
a.upper()
# Out:
# 'INNOMATIC'

# %%
b = "INNOMATIC"
b.lower()
# Out:
# 'innomatic'

# %% [markdown]
# 6.How do you find the index of the first occurence of a substring 'o' with in a string?

# %%
a = "innomatic"
a.index('o')
# Out:
# 3

# %% [markdown]
# 7. Write a python program to reverse the string
# s = "12345" using slicing.

# %%
s = "12345"
s[::-1]
# Out:
# '54321'

# %% [markdown]
# 8.How do you remove leading and trailing whitespace fron a string?

# %%
a = '   programming    '
a.strip()
# Out:
# 'programming'

# %% [markdown]
# 9.Write a python program to slice the string s = "Welcome" and extract the first three characters

# %%
s = "Welcome"
s[:3]
# Out:
# 'Wel'

# %% [markdown]
# 10.Write a python program to slice the string s = "ABCDEFGHI" and return the characters from index 2 to index 8, skipping every second character.

# %%
s = "ABCDEFGHI"
s[2:8:2]
# Out:
# 'CEG'

# %% [markdown]
# 11. Explain five different string methods and explain with example.
#
# 1.upper() method:
# The upper() method return a cpoy of the string in uppercase.

# %%
s = "python"
s.upper()
# Out:
# 'PYTHON'

# %% [markdown]
# 2.capitalize() method make the first character have the upper case and rest lower case

# %%
a = "python"
a.capitalize()
# Out:
# 'Python'

# %% [markdown]
# title()method words start with uppercase characyter
